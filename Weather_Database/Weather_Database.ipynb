# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

#Import time module
import time

# Import linregress
from scipy.stats import linregress

# Import citypy
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combos
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Basic url for OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | umarkhed
# Processing Record 2 of Set 1 | diego de almagro
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | paamiut
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | mujiayingzi
# Processing Record 10 of Set 1 | faanui
# Processing Record 11 of Set 1 | balkanabat
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 1 | chuy
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | concordia
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | kildinstroy
# Processing Record 22 of Set 1 | omboue
# Processing Record 23 of Set 1 | sambava
# Processing Record 24 of Set 1 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 25 of Set 1 | ouesso
# Processing Record 26 of Set 1 | richards bay
# Processing Record 27 of Set 1 | severo-kurilsk
# Processing Record 28 of Set 1 | sagua la grande
# Processing Record 29 of Set 1 | esperance
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | souillac
# Processing Record 33 of Set 1 | buguruslan
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | tiarei
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | falmouth
# Processing Record 40 of Set 1 | batagay
# Processing Record 41 of Set 1 | saint-francois
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | lompoc
# Processing Record 44 of Set 1 | blythe
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | fasa
# Processing Record 48 of Set 1 | namibe
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 1 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 2 | mokolo
# Processing Record 3 of Set 2 | yumen
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | kutum
# Processing Record 7 of Set 2 | aasiaat
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | lasa
# Processing Record 10 of Set 2 | burgeo
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | avera
# Processing Record 13 of Set 2 | xingyi
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | ust-ishim
# Processing Record 16 of Set 2 | baillif
# Processing Record 17 of Set 2 | fort dodge
# Processing Record 18 of Set 2 | marsa matruh
# Processing Record 19 of Set 2 | moyale
# Processing Record 20 of Set 2 | grand gaube
# Processing Record 21 of Set 2 | tianpeng
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | clyde river
# Processing Record 24 of Set 2 | surin
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | kavieng
# Processing Record 30 of Set 2 | atar
# Processing Record 31 of Set 2 | bogorodskoye
# Processing Record 32 of Set 2 | kieta
# Processing Record 33 of Set 2 | turayf
# Processing Record 34 of Set 2 | druzhba
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 2 | longyearbyen
# Processing Record 37 of Set 2 | rock sound
# Processing Record 38 of Set 2 | shiraz
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | glenwood springs
# Processing Record 41 of Set 2 | atambua
# Processing Record 42 of Set 2 | kachiry
# Processing Record 43 of Set 2 | kahului
# Processing Record 44 of Set 2 | vestmannaeyjar
# Processing Record 45 of Set 2 | assomada
# Processing Record 46 of Set 2 | pemberton
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | tabas
# Processing Record 49 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 2 | necochea
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | burica
# City not found. Skipping...
# Processing Record 3 of Set 3 | luderitz
# Processing Record 4 of Set 3 | ketchikan
# Processing Record 5 of Set 3 | nabire
# Processing Record 6 of Set 3 | kiama
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | ola
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 3 | bangsund
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | bandarbeyla
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | hobart
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | santa maria da boa vista
# Processing Record 19 of Set 3 | thompson
# Processing Record 20 of Set 3 | port-cartier
# Processing Record 21 of Set 3 | ostrovnoy
# Processing Record 22 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 23 of Set 3 | beloha
# Processing Record 24 of Set 3 | saint george
# Processing Record 25 of Set 3 | norman wells
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 28 of Set 3 | provideniya
# Processing Record 29 of Set 3 | iqaluit
# Processing Record 30 of Set 3 | ribeira grande
# Processing Record 31 of Set 3 | puerto ayora
# Processing Record 32 of Set 3 | basco
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | mareeba
# Processing Record 35 of Set 3 | jamame
# Processing Record 36 of Set 3 | chokurdakh
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | avarua
# Processing Record 39 of Set 3 | sokoni
# Processing Record 40 of Set 3 | songjianghe
# Processing Record 41 of Set 3 | qaanaaq
# Processing Record 42 of Set 3 | bubaque
# Processing Record 43 of Set 3 | palestina
# Processing Record 44 of Set 3 | mahebourg
# Processing Record 45 of Set 3 | kodiak
# Processing Record 46 of Set 3 | zhangye
# Processing Record 47 of Set 3 | barranca
# Processing Record 48 of Set 3 | trairi
# Processing Record 49 of Set 3 | aksay
# Processing Record 50 of Set 3 | batticaloa
# Processing Record 1 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 4 | hofn
# Processing Record 4 of Set 4 | la palma
# Processing Record 5 of Set 4 | wonthaggi
# Processing Record 6 of Set 4 | khanpur
# Processing Record 7 of Set 4 | broken hill
# Processing Record 8 of Set 4 | vrangel
# Processing Record 9 of Set 4 | axim
# Processing Record 10 of Set 4 | constitucion
# Processing Record 11 of Set 4 | fort nelson
# Processing Record 12 of Set 4 | kununurra
# Processing Record 13 of Set 4 | mersing
# Processing Record 14 of Set 4 | hamilton
# Processing Record 15 of Set 4 | husavik
# Processing Record 16 of Set 4 | taoudenni
# Processing Record 17 of Set 4 | bure
# Processing Record 18 of Set 4 | enshi
# Processing Record 19 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 4 | terney
# Processing Record 21 of Set 4 | tonantins
# Processing Record 22 of Set 4 | astana
# Processing Record 23 of Set 4 | aklavik
# Processing Record 24 of Set 4 | okha
# Processing Record 25 of Set 4 | santa rosa
# Processing Record 26 of Set 4 | trofors
# Processing Record 27 of Set 4 | bonavista
# Processing Record 28 of Set 4 | kailua
# Processing Record 29 of Set 4 | puerto gaitan
# Processing Record 30 of Set 4 | cabo san lucas
# Processing Record 31 of Set 4 | tlaxco
# Processing Record 32 of Set 4 | nanortalik
# Processing Record 33 of Set 4 | tura
# Processing Record 34 of Set 4 | teya
# Processing Record 35 of Set 4 | los llanos de aridane
# Processing Record 36 of Set 4 | tamayo
# Processing Record 37 of Set 4 | ucluelet
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | yilan
# Processing Record 40 of Set 4 | new norfolk
# Processing Record 41 of Set 4 | sechura
# Processing Record 42 of Set 4 | mackay
# Processing Record 43 of Set 4 | longkou
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | coquimbo
# Processing Record 46 of Set 4 | fujin
# Processing Record 47 of Set 4 | isangel
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | inuvik
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | port elizabeth
# Processing Record 2 of Set 5 | airai
# Processing Record 3 of Set 5 | nome
# Processing Record 4 of Set 5 | half moon bay
# Processing Record 5 of Set 5 | mindszent
# Processing Record 6 of Set 5 | valley city
# Processing Record 7 of Set 5 | ulagan
# Processing Record 8 of Set 5 | boali
# Processing Record 9 of Set 5 | cap malheureux
# Processing Record 10 of Set 5 | olinda
# Processing Record 11 of Set 5 | tocache
# Processing Record 12 of Set 5 | playas
# Processing Record 13 of Set 5 | codrington
# Processing Record 14 of Set 5 | mumford
# Processing Record 15 of Set 5 | ancud
# Processing Record 16 of Set 5 | bull savanna
# Processing Record 17 of Set 5 | paciran
# Processing Record 18 of Set 5 | palembang
# Processing Record 19 of Set 5 | gamba
# Processing Record 20 of Set 5 | guerrero negro
# Processing Record 21 of Set 5 | talnakh
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | madera
# Processing Record 24 of Set 5 | camocim
# Processing Record 25 of Set 5 | kadoma
# Processing Record 26 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 5 | aswan
# Processing Record 28 of Set 5 | skodje
# Processing Record 29 of Set 5 | elizabeth city
# Processing Record 30 of Set 5 | kampene
# Processing Record 31 of Set 5 | prata
# Processing Record 32 of Set 5 | suez
# Processing Record 33 of Set 5 | sola
# Processing Record 34 of Set 5 | arlit
# Processing Record 35 of Set 5 | marawi
# Processing Record 36 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 5 | yar-sale
# Processing Record 38 of Set 5 | iracoubo
# Processing Record 39 of Set 5 | padang
# Processing Record 40 of Set 5 | puerto del rosario
# Processing Record 41 of Set 5 | dingle
# Processing Record 42 of Set 5 | pontes e lacerda
# Processing Record 43 of Set 5 | kaeo
# Processing Record 44 of Set 5 | nadym
# Processing Record 45 of Set 5 | sherlovaya gora
# Processing Record 46 of Set 5 | benjamin aceval
# Processing Record 47 of Set 5 | ashland
# Processing Record 48 of Set 5 | killybegs
# Processing Record 49 of Set 5 | pangkalanbuun
# Processing Record 50 of Set 5 | gorzow wielkopolski
# Processing Record 1 of Set 6 | pergamino
# Processing Record 2 of Set 6 | katobu
# Processing Record 3 of Set 6 | labuan
# Processing Record 4 of Set 6 | tessalit
# Processing Record 5 of Set 6 | benghazi
# Processing Record 6 of Set 6 | bambous virieux
# Processing Record 7 of Set 6 | abu samrah
# Processing Record 8 of Set 6 | lehigh acres
# Processing Record 9 of Set 6 | jutai
# Processing Record 10 of Set 6 | salalah
# Processing Record 11 of Set 6 | bacabal
# Processing Record 12 of Set 6 | cherskiy
# Processing Record 13 of Set 6 | turangi
# Processing Record 14 of Set 6 | gohad
# Processing Record 15 of Set 6 | freeport
# Processing Record 16 of Set 6 | andenes
# Processing Record 17 of Set 6 | zyryanka
# Processing Record 18 of Set 6 | hadrut
# Processing Record 19 of Set 6 | pisco
# Processing Record 20 of Set 6 | pinawa
# Processing Record 21 of Set 6 | maragogi
# Processing Record 22 of Set 6 | joao pinheiro
# Processing Record 23 of Set 6 | belaya gora
# Processing Record 24 of Set 6 | gualaquiza
# Processing Record 25 of Set 6 | san juan
# Processing Record 26 of Set 6 | hualmay
# Processing Record 27 of Set 6 | sakakah
# Processing Record 28 of Set 6 | anadyr
# Processing Record 29 of Set 6 | vanderhoof
# Processing Record 30 of Set 6 | tromso
# Processing Record 31 of Set 6 | hithadhoo
# Processing Record 32 of Set 6 | iisalmi
# Processing Record 33 of Set 6 | hassleholm
# Processing Record 34 of Set 6 | carbondale
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | huangchuan
# Processing Record 37 of Set 6 | labuhan
# Processing Record 38 of Set 6 | teknaf
# Processing Record 39 of Set 6 | portland
# Processing Record 40 of Set 6 | la primavera
# Processing Record 41 of Set 6 | bere
# Processing Record 42 of Set 6 | corner brook
# Processing Record 43 of Set 6 | chato
# Processing Record 44 of Set 6 | east london
# Processing Record 45 of Set 6 | sao joao da barra
# Processing Record 46 of Set 6 | jacqueville
# Processing Record 47 of Set 6 | jumla
# Processing Record 48 of Set 6 | tabriz
# Processing Record 49 of Set 6 | vardo
# Processing Record 50 of Set 6 | tecoanapa
# Processing Record 1 of Set 7 | gorin
# Processing Record 2 of Set 7 | hervey bay
# Processing Record 3 of Set 7 | mitsamiouli
# Processing Record 4 of Set 7 | san patricio
# Processing Record 5 of Set 7 | homer
# Processing Record 6 of Set 7 | neyshabur
# Processing Record 7 of Set 7 | rio gallegos
# Processing Record 8 of Set 7 | tahoua
# Processing Record 9 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 7 | maltahohe
# Processing Record 11 of Set 7 | madison
# Processing Record 12 of Set 7 | esmeraldas
# Processing Record 13 of Set 7 | mahibadhoo
# Processing Record 14 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 7 | matara
# Processing Record 16 of Set 7 | stanger
# Processing Record 17 of Set 7 | glace bay
# Processing Record 18 of Set 7 | yantzaza
# Processing Record 19 of Set 7 | flinders
# Processing Record 20 of Set 7 | moscow
# Processing Record 21 of Set 7 | leningradskiy
# Processing Record 22 of Set 7 | ponta delgada
# Processing Record 23 of Set 7 | rancho cucamonga
# Processing Record 24 of Set 7 | alyangula
# Processing Record 25 of Set 7 | hailey
# Processing Record 26 of Set 7 | san ramon
# Processing Record 27 of Set 7 | salinopolis
# Processing Record 28 of Set 7 | lavrentiya
# Processing Record 29 of Set 7 | buala
# Processing Record 30 of Set 7 | colares
# Processing Record 31 of Set 7 | hasaki
# Processing Record 32 of Set 7 | shushtar
# Processing Record 33 of Set 7 | port hedland
# Processing Record 34 of Set 7 | kedougou
# Processing Record 35 of Set 7 | bud
# Processing Record 36 of Set 7 | novi troyany
# Processing Record 37 of Set 7 | viedma
# Processing Record 38 of Set 7 | port hueneme
# Processing Record 39 of Set 7 | itaperucu
# Processing Record 40 of Set 7 | kruisfontein
# Processing Record 41 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 42 of Set 7 | ningxiang
# Processing Record 43 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 7 | ranong
# Processing Record 45 of Set 7 | nelson bay
# Processing Record 46 of Set 7 | bria
# Processing Record 47 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 48 of Set 7 | dunedin
# Processing Record 49 of Set 7 | dabakala
# Processing Record 50 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 1 of Set 8 | kemijarvi
# Processing Record 2 of Set 8 | paita
# Processing Record 3 of Set 8 | ambilobe
# Processing Record 4 of Set 8 | nemuro
# Processing Record 5 of Set 8 | conceicao do araguaia
# Processing Record 6 of Set 8 | cayenne
# Processing Record 7 of Set 8 | formosa
# Processing Record 8 of Set 8 | linchuan
# City not found. Skipping...
# Processing Record 9 of Set 8 | yulara
# Processing Record 10 of Set 8 | puro
# Processing Record 11 of Set 8 | koster
# Processing Record 12 of Set 8 | caravelas
# Processing Record 13 of Set 8 | kuusamo
# Processing Record 14 of Set 8 | shitanjing
# Processing Record 15 of Set 8 | evensk
# Processing Record 16 of Set 8 | bac lieu
# Processing Record 17 of Set 8 | baringo
# Processing Record 18 of Set 8 | bathsheba
# Processing Record 19 of Set 8 | puerto escondido
# Processing Record 20 of Set 8 | leo
# Processing Record 21 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 8 | shirokiy
# Processing Record 23 of Set 8 | kos
# Processing Record 24 of Set 8 | russell
# Processing Record 25 of Set 8 | havoysund
# Processing Record 26 of Set 8 | yakima
# Processing Record 27 of Set 8 | te anau
# Processing Record 28 of Set 8 | pavlodar
# Processing Record 29 of Set 8 | kokopo
# Processing Record 30 of Set 8 | akureyri
# Processing Record 31 of Set 8 | dinghai
# Processing Record 32 of Set 8 | moree
# Processing Record 33 of Set 8 | gaogou
# Processing Record 34 of Set 8 | chegutu
# Processing Record 35 of Set 8 | beringovskiy
# Processing Record 36 of Set 8 | hay river
# Processing Record 37 of Set 8 | hit
# Processing Record 38 of Set 8 | cedar city
# Processing Record 39 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 8 | harbour breton
# Processing Record 41 of Set 8 | marsh harbour
# Processing Record 42 of Set 8 | yerbogachen
# Processing Record 43 of Set 8 | faya
# Processing Record 44 of Set 8 | bethanien
# Processing Record 45 of Set 8 | laramie
# Processing Record 46 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 8 | karmala
# Processing Record 48 of Set 8 | san carlos
# Processing Record 49 of Set 8 | puerto baquerizo moreno
# Processing Record 50 of Set 8 | mogadishu
# Processing Record 1 of Set 9 | henties bay
# Processing Record 2 of Set 9 | myitkyina
# Processing Record 3 of Set 9 | agadez
# Processing Record 4 of Set 9 | itarema
# Processing Record 5 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 6 of Set 9 | san pedro
# Processing Record 7 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 9 | vasvar
# Processing Record 9 of Set 9 | kargat
# Processing Record 10 of Set 9 | teofilo otoni
# Processing Record 11 of Set 9 | cabedelo
# Processing Record 12 of Set 9 | athabasca
# Processing Record 13 of Set 9 | pangody
# Processing Record 14 of Set 9 | pangnirtung
# Processing Record 15 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 9 | waingapu
# Processing Record 18 of Set 9 | tuatapere
# Processing Record 19 of Set 9 | yamada
# Processing Record 20 of Set 9 | magadan
# Processing Record 21 of Set 9 | yerofey pavlovich
# Processing Record 22 of Set 9 | kailahun
# Processing Record 23 of Set 9 | wadi maliz
# Processing Record 24 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 25 of Set 9 | palmer
# Processing Record 26 of Set 9 | westport
# Processing Record 27 of Set 9 | garissa
# Processing Record 28 of Set 9 | lorengau
# Processing Record 29 of Set 9 | tokur
# Processing Record 30 of Set 9 | urucara
# Processing Record 31 of Set 9 | socoltenango
# Processing Record 32 of Set 9 | laguna
# Processing Record 33 of Set 9 | jalu
# Processing Record 34 of Set 9 | severnoye
# Processing Record 35 of Set 9 | san quintin
# Processing Record 36 of Set 9 | champerico
# Processing Record 37 of Set 9 | naze
# Processing Record 38 of Set 9 | chengmai
# City not found. Skipping...
# Processing Record 39 of Set 9 | bakchar
# Processing Record 40 of Set 9 | chapais
# Processing Record 41 of Set 9 | hibbing
# Processing Record 42 of Set 9 | praia da vitoria
# Processing Record 43 of Set 9 | izhma
# Processing Record 44 of Set 9 | pryozerne
# Processing Record 45 of Set 9 | conde
# Processing Record 46 of Set 9 | gorodets
# Processing Record 47 of Set 9 | bongandanga
# Processing Record 48 of Set 9 | hobyo
# Processing Record 49 of Set 9 | chimbote
# Processing Record 50 of Set 9 | makakilo city
# Processing Record 1 of Set 10 | atocha
# Processing Record 2 of Set 10 | okhotsk
# Processing Record 3 of Set 10 | novopokrovka
# Processing Record 4 of Set 10 | buraydah
# Processing Record 5 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 6 of Set 10 | kloulklubed
# Processing Record 7 of Set 10 | launceston
# Processing Record 8 of Set 10 | mehamn
# Processing Record 9 of Set 10 | marsaxlokk
# Processing Record 10 of Set 10 | vikulovo
# Processing Record 11 of Set 10 | janauba
# Processing Record 12 of Set 10 | sao lourenco do sul
# Processing Record 13 of Set 10 | mount isa
# Processing Record 14 of Set 10 | xiaoyi
# Processing Record 15 of Set 10 | anzio
# Processing Record 16 of Set 10 | thinadhoo
# Processing Record 17 of Set 10 | kimbe
# Processing Record 18 of Set 10 | isla vista
# Processing Record 19 of Set 10 | balasheyka
# Processing Record 20 of Set 10 | thurles
# Processing Record 21 of Set 10 | uray
# Processing Record 22 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 10 | mabay
# Processing Record 24 of Set 10 | kharan
# Processing Record 25 of Set 10 | lagoa
# Processing Record 26 of Set 10 | touros
# Processing Record 27 of Set 10 | vila velha
# Processing Record 28 of Set 10 | makat
# Processing Record 29 of Set 10 | kangaatsiaq
# Processing Record 30 of Set 10 | acarau
# Processing Record 31 of Set 10 | mega
# Processing Record 32 of Set 10 | aden
# Processing Record 33 of Set 10 | cape canaveral
# Processing Record 34 of Set 10 | sao felix do xingu
# Processing Record 35 of Set 10 | belmonte
# Processing Record 36 of Set 10 | ambon
# Processing Record 37 of Set 10 | zaysan
# Processing Record 38 of Set 10 | loiza
# Processing Record 39 of Set 10 | rorvik
# Processing Record 40 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 10 | carmen
# Processing Record 42 of Set 10 | visnes
# Processing Record 43 of Set 10 | porto velho
# Processing Record 44 of Set 10 | nacala
# Processing Record 45 of Set 10 | kitgum
# Processing Record 46 of Set 10 | nairobi
# Processing Record 47 of Set 10 | jabinyanah
# Processing Record 48 of Set 10 | orlik
# Processing Record 49 of Set 10 | trapani
# Processing Record 50 of Set 10 | malakal
# Processing Record 1 of Set 11 | rawson
# Processing Record 2 of Set 11 | shimoda
# Processing Record 3 of Set 11 | kyshtovka
# Processing Record 4 of Set 11 | khash
# Processing Record 5 of Set 11 | pinega
# Processing Record 6 of Set 11 | san andres
# Processing Record 7 of Set 11 | dongning
# Processing Record 8 of Set 11 | antsohihy
# Processing Record 9 of Set 11 | pimentel
# Processing Record 10 of Set 11 | svetlogorsk
# Processing Record 11 of Set 11 | gimli
# Processing Record 12 of Set 11 | kyren
# Processing Record 13 of Set 11 | sovetskiy
# Processing Record 14 of Set 11 | santo antonio do leverger
# Processing Record 15 of Set 11 | emmett
# Processing Record 16 of Set 11 | kon tum
# Processing Record 17 of Set 11 | phnum penh
# City not found. Skipping...
# Processing Record 18 of Set 11 | college
# Processing Record 19 of Set 11 | bourail
# Processing Record 20 of Set 11 | broome
# Processing Record 21 of Set 11 | smithers
# Processing Record 22 of Set 11 | khilok
# Processing Record 23 of Set 11 | saldanha
# Processing Record 24 of Set 11 | yatou
# Processing Record 25 of Set 11 | dakar
# Processing Record 26 of Set 11 | rio grande
# Processing Record 27 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 28 of Set 11 | hokitika
# Processing Record 29 of Set 11 | bereda
# Processing Record 30 of Set 11 | anloga
# Processing Record 31 of Set 11 | yoichi
# Processing Record 32 of Set 11 | kidal
# Processing Record 33 of Set 11 | vao
# Processing Record 34 of Set 11 | klaksvik
# Processing Record 35 of Set 11 | krasnyy chikoy
# Processing Record 36 of Set 11 | sisimiut
# Processing Record 37 of Set 11 | sinnamary
# Processing Record 38 of Set 11 | kahta
# Processing Record 39 of Set 11 | grants pass
# Processing Record 40 of Set 11 | tucuman
# Processing Record 41 of Set 11 | novoye atlashevo
# City not found. Skipping...
# Processing Record 42 of Set 11 | khvalynsk
# Processing Record 43 of Set 11 | cukai
# Processing Record 44 of Set 11 | vanavara
# Processing Record 45 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 46 of Set 11 | haikou
# Processing Record 47 of Set 11 | gao
# Processing Record 48 of Set 11 | zabrani
# Processing Record 49 of Set 11 | csengele
# Processing Record 50 of Set 11 | roma
# Processing Record 1 of Set 12 | maniitsoq
# Processing Record 2 of Set 12 | dryden
# Processing Record 3 of Set 12 | eureka
# Processing Record 4 of Set 12 | bose
# Processing Record 5 of Set 12 | maceio
# Processing Record 6 of Set 12 | bilma
# Processing Record 7 of Set 12 | yarmouth
# Processing Record 8 of Set 12 | sindor
# Processing Record 9 of Set 12 | sept-iles
# Processing Record 10 of Set 12 | kilindoni
# Processing Record 11 of Set 12 | saint-pierre
# Processing Record 12 of Set 12 | glendive
# Processing Record 13 of Set 12 | sembe
# Processing Record 14 of Set 12 | iguape
# Processing Record 15 of Set 12 | festus
# Processing Record 16 of Set 12 | komsomolskiy
# Processing Record 17 of Set 12 | tabou
# Processing Record 18 of Set 12 | saint-georges
# Processing Record 19 of Set 12 | barcelos
# Processing Record 20 of Set 12 | auchi
# Processing Record 21 of Set 12 | leh
# Processing Record 22 of Set 12 | bowen
# Processing Record 23 of Set 12 | tecolutla
# Processing Record 24 of Set 12 | srivardhan
# Processing Record 25 of Set 12 | wajima
# Processing Record 26 of Set 12 | almeirim
# Processing Record 27 of Set 12 | pacific grove
# Processing Record 28 of Set 12 | colon
# Processing Record 29 of Set 12 | outlook
# Processing Record 30 of Set 12 | tondi
# Processing Record 31 of Set 12 | roswell
# Processing Record 32 of Set 12 | hattiesburg
# Processing Record 33 of Set 12 | santa fe
# Processing Record 34 of Set 12 | tamandare
# Processing Record 35 of Set 12 | ouargaye
# Processing Record 36 of Set 12 | grootfontein
# Processing Record 37 of Set 12 | morro bay
# Processing Record 38 of Set 12 | kyaiklat
# Processing Record 39 of Set 12 | yekaterinoslavka
# Processing Record 40 of Set 12 | yuancheng
# Processing Record 41 of Set 12 | mandera
# Processing Record 42 of Set 12 | gravdal
# Processing Record 43 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 12 | campbell river
# Processing Record 45 of Set 12 | poum
# Processing Record 46 of Set 12 | port blair
# Processing Record 47 of Set 12 | malitbog
# Processing Record 48 of Set 12 | lebork
# Processing Record 49 of Set 12 | geraldton
# Processing Record 50 of Set 12 | puerto asis
# Processing Record 1 of Set 13 | srednekolymsk
# Processing Record 2 of Set 13 | west wendover
# Processing Record 3 of Set 13 | port macquarie
# Processing Record 4 of Set 13 | whitehorse
# Processing Record 5 of Set 13 | muzhi
# Processing Record 6 of Set 13 | sorland
# Processing Record 7 of Set 13 | berdigestyakh
# Processing Record 8 of Set 13 | asau
# Processing Record 9 of Set 13 | baoqing
# Processing Record 10 of Set 13 | santa teresa
# Processing Record 11 of Set 13 | guadalajara
# Processing Record 12 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 13 | bar harbor
# Processing Record 14 of Set 13 | port hardy
# Processing Record 15 of Set 13 | simbahan
# Processing Record 16 of Set 13 | griffith
# Processing Record 17 of Set 13 | normandin
# Processing Record 18 of Set 13 | donskoye
# Processing Record 19 of Set 13 | coihaique
# Processing Record 20 of Set 13 | qostanay
# Processing Record 21 of Set 13 | kapit
# Processing Record 22 of Set 13 | tanjong tokong
# City not found. Skipping...
# Processing Record 23 of Set 13 | sorong
# Processing Record 24 of Set 13 | walvis bay
# Processing Record 25 of Set 13 | yokadouma
# Processing Record 26 of Set 13 | wilmington
# Processing Record 27 of Set 13 | bosanski samac
# Processing Record 28 of Set 13 | aguas vermelhas
# Processing Record 29 of Set 13 | isilkul
# Processing Record 30 of Set 13 | rio casca
# Processing Record 31 of Set 13 | arman
# Processing Record 32 of Set 13 | vaitape
# Processing Record 33 of Set 13 | neryungri
# Processing Record 34 of Set 13 | ulaanbaatar
# Processing Record 35 of Set 13 | sao jose da coroa grande
# Processing Record 36 of Set 13 | itororo
# Processing Record 37 of Set 13 | nalut
# Processing Record 38 of Set 13 | kenora
# Processing Record 39 of Set 13 | toamasina
# Processing Record 40 of Set 13 | egvekinot
# Processing Record 41 of Set 13 | butembo
# Processing Record 42 of Set 13 | tocopilla
# Processing Record 43 of Set 13 | bullhead city
# Processing Record 44 of Set 13 | margate
# Processing Record 45 of Set 13 | shahreza
# Processing Record 46 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 13 | bafq
# Processing Record 48 of Set 13 | lebanon
# Processing Record 49 of Set 13 | constantine
# Processing Record 50 of Set 13 | sterling
# Processing Record 1 of Set 14 | pampierstad
# Processing Record 2 of Set 14 | samarai
# Processing Record 3 of Set 14 | kasulu
# Processing Record 4 of Set 14 | carutapera
# Processing Record 5 of Set 14 | san cristobal
# Processing Record 6 of Set 14 | ossora
# Processing Record 7 of Set 14 | rocky mountain house
# Processing Record 8 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 14 | bali
# Processing Record 10 of Set 14 | cockburn town
# Processing Record 11 of Set 14 | manali
# Processing Record 12 of Set 14 | mnogovershinnyy
# Processing Record 13 of Set 14 | monteagudo
# Processing Record 14 of Set 14 | anzoategui
# Processing Record 15 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 14 | linqiong
# Processing Record 17 of Set 14 | port lincoln
# Processing Record 18 of Set 14 | saqqez
# Processing Record 19 of Set 14 | villa carlos paz
# Processing Record 20 of Set 14 | camacha
# Processing Record 21 of Set 14 | drayton valley
# Processing Record 22 of Set 14 | umm lajj
# Processing Record 23 of Set 14 | west plains
# Processing Record 24 of Set 14 | adrar
# Processing Record 25 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 26 of Set 14 | hanstholm
# Processing Record 27 of Set 14 | fomboni
# Processing Record 28 of Set 14 | obernai
# Processing Record 29 of Set 14 | sitka
# Processing Record 30 of Set 14 | jibuti
# Processing Record 31 of Set 14 | tefe
# Processing Record 32 of Set 14 | puerto lempira
# Processing Record 33 of Set 14 | vila do maio
# Processing Record 34 of Set 14 | kindu
# Processing Record 35 of Set 14 | strezhevoy
# Processing Record 36 of Set 14 | brae
# Processing Record 37 of Set 14 | tazmalt
# Processing Record 38 of Set 14 | esil
# Processing Record 39 of Set 14 | dinar
# Processing Record 40 of Set 14 | qaqortoq
# Processing Record 41 of Set 14 | olafsvik
# Processing Record 42 of Set 14 | lamar
# Processing Record 43 of Set 14 | marzuq
# Processing Record 44 of Set 14 | anchorage
# Processing Record 45 of Set 14 | novi iskar
# Processing Record 46 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 47 of Set 14 | aanekoski
# Processing Record 48 of Set 14 | sogdiondon
# City not found. Skipping...
# Processing Record 49 of Set 14 | santa marta
# Processing Record 50 of Set 14 | mount gambier
# Processing Record 1 of Set 15 | najran
# Processing Record 2 of Set 15 | vostok
# Processing Record 3 of Set 15 | taltal
# Processing Record 4 of Set 15 | mounana
# Processing Record 5 of Set 15 | talmenka
# Processing Record 6 of Set 15 | owase
# Processing Record 7 of Set 15 | saint-joseph
# Processing Record 8 of Set 15 | la libertad
# Processing Record 9 of Set 15 | adelaide
# Processing Record 10 of Set 15 | muros
# Processing Record 11 of Set 15 | liwale
# Processing Record 12 of Set 15 | kracheh
# City not found. Skipping...
# Processing Record 13 of Set 15 | acapulco
# Processing Record 14 of Set 15 | quelimane
# Processing Record 15 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 15 | pattaya
# Processing Record 17 of Set 15 | great falls
# Processing Record 18 of Set 15 | lata
# Processing Record 19 of Set 15 | pakxan
# Processing Record 20 of Set 15 | florida
# Processing Record 21 of Set 15 | port augusta
# Processing Record 22 of Set 15 | umarga
# Processing Record 23 of Set 15 | nagato
# Processing Record 24 of Set 15 | alta floresta
# Processing Record 25 of Set 15 | baiyin
# Processing Record 26 of Set 15 | nuuk
# Processing Record 27 of Set 15 | kathu
# Processing Record 28 of Set 15 | murgab
# Processing Record 29 of Set 15 | betafo
# Processing Record 30 of Set 15 | dubti
# Processing Record 31 of Set 15 | pavlogradka
# Processing Record 32 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 15 | talcahuano
# Processing Record 34 of Set 15 | sawtell
# Processing Record 35 of Set 15 | nyimba
# Processing Record 36 of Set 15 | sabla
# Processing Record 37 of Set 15 | baherden
# Processing Record 38 of Set 15 | alta
# Processing Record 39 of Set 15 | bairiki
# Processing Record 40 of Set 15 | anapskaya
# Processing Record 41 of Set 15 | maningrida
# Processing Record 42 of Set 15 | zhenlai
# Processing Record 43 of Set 15 | kirakira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of dictionaries to pandas dataframe
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Umarkhed  19.6000   77.7000     80.35        75         100
# 1  Diego De Almagro -26.3667  -70.0500     51.82        44          14
# 2           Mataura -46.1927  168.8643     39.47        97          91
# 3           Paamiut  61.9940  -49.6678     43.36        88          98
# 4             Pevek  69.7008  170.3133     37.54        81          27
#
#    Wind Speed Country Weather Description                 Date
# 0        2.35      IN     overcast clouds  2021-08-08 23:59:25
# 1        2.55      CL          few clouds  2021-08-08 23:59:25
# 2        5.50      NZ     overcast clouds  2021-08-08 23:59:26
# 3        0.25      GL     overcast clouds  2021-08-08 23:52:30
# 4       10.87      RU    scattered clouds  2021-08-08 23:59:26

# %%
# Rearrange columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Weather Description", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#                City Country                 Date      Lat       Lng  \
# 0          Umarkhed      IN  2021-08-08 23:59:25  19.6000   77.7000
# 1  Diego De Almagro      CL  2021-08-08 23:59:25 -26.3667  -70.0500
# 2           Mataura      NZ  2021-08-08 23:59:26 -46.1927  168.8643
# 3           Paamiut      GL  2021-08-08 23:52:30  61.9940  -49.6678
# 4             Pevek      RU  2021-08-08 23:59:26  69.7008  170.3133
#
#   Weather Description  Max Temp  Humidity  Cloudiness  Wind Speed
# 0     overcast clouds     80.35        75         100        2.35
# 1          few clouds     51.82        44          14        2.55
# 2     overcast clouds     39.47        97          91        5.50
# 3     overcast clouds     43.36        88          98        0.25
# 4    scattered clouds     37.54        81          27       10.87

# %%
# Export the City Data Dataframe into a CSV
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
